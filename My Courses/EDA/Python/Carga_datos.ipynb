# %% [markdown]
# # Carga de información

# %% [markdown]
# ## Estructurados

# %%
import pandas as pd
import sqlite3
# let's make the connection with our database
conn = sqlite3.connect("FPA_FOD_20170508.sqlite")
# we are going to use pandas to query a table
fires = pd.read_sql_query("SELECT * FROM Fires LIMIT 5", conn)
fires.head()
# Out:
#    OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 0         1       1  FS-1418826                FED   FS-FIRESTAT
# 1         2       2  FS-1418827                FED   FS-FIRESTAT
# 2         3       3  FS-1418835                FED   FS-FIRESTAT
# 3         4       4  FS-1418845                FED   FS-FIRESTAT
# 4         5       5  FS-1418847                FED   FS-FIRESTAT
#
#   NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  NWCG_REPORTING_UNIT_NAME  \
# 0                    FS                USCAPNF    Plumas National Forest
# 1                    FS                USCAENF  Eldorado National Forest
# 2                    FS                USCAENF  Eldorado National Forest
# 3                    FS                USCAENF  Eldorado National Forest
# 4                    FS                USCAENF  Eldorado National Forest
#
#   SOURCE_REPORTING_UNIT SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS  \
# ...

# %% [markdown]
# ***

# %%
import pandas as pd

# %%
df_park = pd.read_csv('https://raw.githubusercontent.com/urcuqui/Data-Science/master/datasets/parks.csv', index_col=['Park Code'], encoding='utf-8')
df_park.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, ACAD to ZION
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Park Name  56 non-null     object
#  1   State      56 non-null     object
#  2   Acres      56 non-null     int64
#  3   Latitude   56 non-null     float64
#  4   Longitude  56 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.6+ KB

# %%
df_park.dtypes
# Out:
# Park Name     object
# State         object
# Acres          int64
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
print(df_park.shape)
print("")
print(len(df_park))
print("")
print(df_park.columns)
# Out:
# (56, 5)
#
# 56
#
# Index(['Park Name', 'State', 'Acres', 'Latitude', 'Longitude'], dtype='object')

# %%
df_park.rename({'Park Name': 'park_name', 'State': 'state', 'Acres': 'acres', 'Latitude': 'latitude', 
                'Longitude': 'longitude'}, axis='columns').copy().head()
# Out:
#                         park_name state   acres  latitude  longitude
# Park Code
# ACAD         Acadia National Park    ME   47390     44.35     -68.21
# ARCH         Arches National Park    UT   76519     38.68    -109.57
# BADL       Badlands National Park    SD  242756     43.75    -102.50
# BIBE       Big Bend National Park    TX  801163     29.25    -103.25
# BISC       Biscayne National Park    FL  172924     25.65     -80.08

# %%
df_park.columns.str.replace(' ', '_').str.lower()
# Out:
# Index(['park_name', 'state', 'acres', 'latitude', 'longitude'], dtype='object')

# %%
df_park.columns = df_park.columns.str.replace(' ', '_').str.lower()
df_park.columns
# Out:
# Index(['park_name', 'state', 'acres', 'latitude', 'longitude'], dtype='object')

# %%
df_park.describe()
# Out:
#               acres   latitude   longitude
# count  5.600000e+01  56.000000   56.000000
# mean   9.279291e+05  41.233929 -113.234821
# std    1.709258e+06  10.908831   22.440287
# min    5.550000e+03  19.380000 -159.280000
# 25%    6.901050e+04  35.527500 -121.570000
# 50%    2.387645e+05  38.550000 -110.985000
# 75%    8.173602e+05  46.880000 -103.400000
# max    8.323148e+06  67.780000  -68.210000

# %%
df_park.describe(include="all")
# Out:
#                     park_name state         acres   latitude   longitude
# count                      56    56  5.600000e+01  56.000000   56.000000
# unique                     56    27           NaN        NaN         NaN
# top     Redwood National Park    AK           NaN        NaN         NaN
# freq                        1     8           NaN        NaN         NaN
# mean                      NaN   NaN  9.279291e+05  41.233929 -113.234821
# std                       NaN   NaN  1.709258e+06  10.908831   22.440287
# min                       NaN   NaN  5.550000e+03  19.380000 -159.280000
# 25%                       NaN   NaN  6.901050e+04  35.527500 -121.570000
# 50%                       NaN   NaN  2.387645e+05  38.550000 -110.985000
# 75%                       NaN   NaN  8.173602e+05  46.880000 -103.400000
# max                       NaN   NaN  8.323148e+06  67.780000  -68.210000

# %%
df_park.describe(include="O")
# df_park.state = df_park.state.astype("category")
# df_park.describe(include="category")
# Out:
#                     park_name state
# count                      56    56
# unique                     56    27
# top     Redwood National Park    AK
# freq                        1     8

# %%
df_park.describe(include="number")
# Out:
#               acres   latitude   longitude
# count  5.600000e+01  56.000000   56.000000
# mean   9.279291e+05  41.233929 -113.234821
# std    1.709258e+06  10.908831   22.440287
# min    5.550000e+03  19.380000 -159.280000
# 25%    6.901050e+04  35.527500 -121.570000
# 50%    2.387645e+05  38.550000 -110.985000
# 75%    8.173602e+05  46.880000 -103.400000
# max    8.323148e+06  67.780000  -68.210000

# %%
df_park.state.value_counts()
# Out:
# AK            8
# CA            7
# UT            5
# CO            4
# FL            3
# AZ            3
# WA            3
# TX            2
# HI            2
# SD            2
# OH            1
# MT            1
# TN, NC        1
# NM            1
# NV            1
# MN            1
# VA            1
# AR            1
# ND            1
# WY, MT, ID    1
# ME            1
# SC            1
# WY            1
# MI            1
# KY            1
# OR            1
# CA, NV        1
# Name: state, dtype: int64

# %%
df_park.head(3)
# Out:
#                         park_name state   acres  latitude  longitude
# Park Code
# ACAD         Acadia National Park    ME   47390     44.35     -68.21
# ARCH         Arches National Park    UT   76519     38.68    -109.57
# BADL       Badlands National Park    SD  242756     43.75    -102.50

# %%
df_park['park_name'][0:8]  # slice – los primeros ocho registros
# Out:
# Park Code
# ACAD                          Acadia National Park
# ARCH                          Arches National Park
# BADL                        Badlands National Park
# BIBE                        Big Bend National Park
# BISC                        Biscayne National Park
# BLCA    Black Canyon of the Gunnison National Park
# BRCA                    Bryce Canyon National Park
# CANY                     Canyonlands National Park
# Name: park_name, dtype: object

# %% [markdown]
# + iloc, para indices numericos. [fila, columna]

# %%
df_park.iloc[0] # obtenemos el primer registro
# Out:
# park_name    Acadia National Park
# state                          ME
# acres                       47390
# latitude                    44.35
# longitude                  -68.21
# Name: ACAD, dtype: object

# %%
df_park.iloc[1, 2:4] # obtenemos del segundo registro las columnas 2 y 3
# Out:
# acres       76519
# latitude    38.68
# Name: ARCH, dtype: object

# %%
df_park.iloc[1:3, [1,2]] # podemos pasar una list
# Out:
#           state   acres
# Park Code
# ARCH         UT   76519
# BADL         SD  242756

# %% [markdown]
# + loc, [filas, columnas] para indices no numericos

# %%
df_park.index # obtenemos los índices, es decir, la variable “Park Code”
# Out:
# Index(['ACAD', 'ARCH', 'BADL', 'BIBE', 'BISC', 'BLCA', 'BRCA', 'CANY', 'CARE',
#        'CAVE', 'CHIS', 'CONG', 'CRLA', 'CUVA', 'DENA', 'DEVA', 'DRTO', 'EVER',
#        'GAAR', 'GLAC', 'GLBA', 'GRBA', 'GRCA', 'GRSA', 'GRSM', 'GRTE', 'GUMO',
#        'HALE', 'HAVO', 'HOSP', 'ISRO', 'JOTR', 'KATM', 'KEFJ', 'KOVA', 'LACL',
#        'LAVO', 'MACA', 'MEVE', 'MORA', 'NOCA', 'OLYM', 'PEFO', 'PINN', 'REDW',
#        'ROMO', 'SAGU', 'SEKI', 'SHEN', 'THRO', 'VOYA', 'WICA', 'WRST', 'YELL',
#        'YOSE', 'ZION'],
#       dtype='object', name='Park Code')

# %%
df_park.loc['ACAD', 'latitude']
# Out:
# 44.35

# %%
df_park.loc[["ACAD","ARCH"]] # obtenemos dos registros
# Out:
#                       park_name state  acres  latitude  longitude
# Park Code
# ACAD       Acadia National Park    ME  47390     44.35     -68.21
# ARCH       Arches National Park    UT  76519     38.68    -109.57

# %%
df_park.loc[:, ["latitude", "acres"]].head() # la latitude y acres de todos los registros
# Out:
#            latitude   acres
# Park Code
# ACAD          44.35   47390
# ARCH          38.68   76519
# BADL          43.75  242756
# BIBE          29.25  801163
# BISC          25.65  172924

# %% [markdown]
# Finalmente ya es cuestión del programador el proceso de indexación y selección de los datos.

# %%
df_park.iloc[1:3].loc[: ,['state','park_name']]
# Out:
#           state               park_name
# Park Code
# ARCH         UT    Arches National Park
# BADL         SD  Badlands National Park

# %%
df_park.loc[(df_park.state == "CA") & (df_park.acres >= 700000)]
# Out:
#                                          park_name state   acres  latitude  \
# Park Code
# JOTR                     Joshua Tree National Park    CA  789745     33.79
# SEKI       Sequoia and Kings Canyon National Parks    CA  865952     36.43
# YOSE                        Yosemite National Park    CA  761266     37.83
#
#            longitude
# Park Code
# JOTR         -115.90
# SEKI         -118.68
# YOSE         -119.50

# %% [markdown]
# Pandas provee otros métodos para selección condicional, un ejemplo de estos es isin(). isin selecciona los datos cuyo valor pertenece a una lista.
#
# _Supongamos que estamos interesados obtener los datos de los estados de ‘CA’ y ‘AK’_

# %%
df_park[df_park.state.isin(['AK', 'CA'])]
# Out:
#                                                 park_name state    acres  \
# Park Code
# CHIS                        Channel Islands National Park    CA   249561
# DENA                    Denali National Park and Preserve    AK  3372402
# GAAR       Gates Of The Arctic National Park and Preserve    AK  7523898
# GLBA               Glacier Bay National Park and Preserve    AK  3224840
# JOTR                            Joshua Tree National Park    CA   789745
# KATM                    Katmai National Park and Preserve    AK  3674530
# KEFJ                           Kenai Fjords National Park    AK   669983
# KOVA                           Kobuk Valley National Park    AK  1750717
# LACL                Lake Clark National Park and Preserve    AK  2619733
# LAVO                        Lassen Volcanic National Park    CA   106372
# PINN                              Pinnacles National Park    CA    26606
# REDW                                Redwood National Park    CA   112512
# ...

# %% [markdown]
# La asignación de datos a una DataFrame es relativamente sencilla, podemos aplicar los pasos vistos y asignar los registros a un valor constante.
#
# _Supongamos que deseamos cambiar los registros que tienen un estado 'AK' por NaN_

# %%
df_park.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, ACAD to ZION
# Data columns (total 5 columns):
# park_name    56 non-null object
# state        56 non-null category
# acres        56 non-null int64
# latitude     56 non-null float64
# longitude    56 non-null float64
# dtypes: category(1), float64(2), int64(1), object(1)
# memory usage: 6.2+ KB

# %%
import numpy as np

df_park.loc[df_park.state =='AK', 'state']= np.nan
df_park.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, ACAD to ZION
# Data columns (total 5 columns):
# park_name    56 non-null object
# state        48 non-null category
# acres        56 non-null int64
# latitude     56 non-null float64
# longitude    56 non-null float64
# dtypes: category(1), float64(2), int64(1), object(1)
# memory usage: 6.2+ KB

# %%
print("shape sin null {}".format(df_park[df_park.state.notnull()].shape))
print("shape con null {}".format(df_park[df_park.state.isnull()].shape))
# Out:
# shape sin null (48, 5)
# shape con null (8, 5)

# %% [markdown]
# ***

# %% [markdown]
# ### Proyecto
#
# ```
# Desarrolle un portafolio de soluciones de analítica, tan completo como le sea posible, para una
# tienda en línea. Algunas alternativas incluyen: proyecciones mensuales de número de clientes y
# ventas, análisis de las preferencias de los clientes por los productos, motor de recomendación de
# productos por cliente, etc. Gómez, J.
# ```
# https://archive.ics.uci.edu/ml/datasets/Online+Retail+II#

# %% [markdown]
# **Attribute Information:**
#
# + InvoiceNo: Invoice number. Nominal. A 6-digit integral number uniquely assigned to each transaction. If this code starts with the letter 'c', it indicates a cancellation.
# + StockCode: Product (item) code. Nominal. A 5-digit integral number uniquely assigned to each distinct product.
# + Description: Product (item) name. Nominal.
# + Quantity: The quantities of each product (item) per transaction. Numeric.
# + InvoiceDate: Invice date and time. Numeric. The day and time when a transaction was generated.
# + UnitPrice: Unit price. Numeric. Product price per unit in sterling (Â£).
# + CustomerID: Customer number. Nominal. A 5-digit integral number uniquely assigned to each customer.
# + Country: Country name. Nominal. The name of the country where a customer resides.

# %%
import pandas as pd

pd.read_excel("https://archive.ics.uci.edu/ml/machine-learning-databases/00502/online_retail_II.xlsx").head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# # Semiestructurados

# %%
# hay que tener encuenta que el json debe estar normalizado
import pandas as pd
pd.read_json("https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/data.json").head()
# Out:
#    integer            datetime  category
# 0        5 2015-01-01 00:00:00         0
# 1        5 2015-01-01 00:00:01         0
# 2        9 2015-01-01 00:00:02         0
# 3        6 2015-01-01 00:00:03         0
# 4        6 2015-01-01 00:00:04         0

# %% [markdown]
# # No estructurados

# %% [markdown]
# ### imagenes

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/32/OpenCV_Logo_with_text_svg_version.svg/1200px-OpenCV_Logo_with_text_svg_version.svg.png" style="height:100px"/>
#
# + https://earthdata.nasa.gov/
#
# + https://docs.opencv.org/master/d5/de5/tutorial_py_setup_in_windows.html

# %%
# !python -V
# Out:
# Python 3.8.8

# %% [markdown]
# !conda install -c conda-forge opencv

# %%
import cv2 as cv

# %%
cv.__version__
# Out:
# '4.0.1'

# %%
cv.imread("images/000001.jpg")
# type(cv.imread("images/000001.jpg"))
# Out:
# array([[[194, 231, 253],
#         [194, 231, 253],
#         [194, 231, 253],
#         ...,
#         [225, 226, 247],
#         [222, 238, 254],
#         [222, 238, 254]],
#
#        [[194, 231, 253],
#         [194, 231, 253],
#         [194, 231, 253],
#         ...,
#         [225, 228, 249],
#         [222, 238, 254],
#         [222, 238, 254]],
#
#        [[194, 231, 253],
#         [194, 231, 253],
#         [194, 231, 253],
#         ...,
#         [227, 231, 250],
#         [223, 239, 255],
#         [223, 239, 255]],
#
#        ...,
#
#        [[ 26,  74, 140],
#         [  1,  48, 116],
#         [ 33,  78, 146],
#         ...,
#         [ 28,  55, 122],
#         [ 30,  56, 122],
#         [ 30,  56, 122]],
#
#        [[ 15,  62, 130],
#         [ 23,  70, 138],
#         [ 53,  98, 166],
#         ...,
#         [ 20,  49, 118],
#         [ 24,  51, 118],
#         [ 24,  51, 118]],
#
#        [[ 53, 100, 168],
#         [ 89, 136, 204],
#         [132, 177, 245],
# ...

# %%
cv.imread("images/000001.jpg", cv.IMREAD_GRAYSCALE)
# Out:
# array([[233, 233, 233, ..., 232, 241, 241],
#        [233, 233, 233, ..., 234, 241, 241],
#        [233, 233, 233, ..., 236, 242, 242],
#        ...,
#        [ 88,  63,  93, ...,  72,  73,  73],
#        [ 77,  85, 113, ...,  66,  68,  68],
#        [115, 151, 192, ...,  66,  68,  68]], dtype=uint8)

# %%
img = cv.imread("images/000001.jpg",cv.IMREAD_GRAYSCALE)

# %%
cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread("images/000001.jpg")
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv.cornerHarris(gray,2,3,0.04)
#result is dilated for marking the corners, not important
dst = cv.dilate(dst,None)
# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]
plt.imshow(img)
plt.show()

# %% [markdown]
# *matplotlib*

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('images/000010.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

imgt = mpimg.imread('images/000010.jpg')
print(type(imgt))
plt.figure(figsize = (5,5))
plt.imshow(imgt)
plt.show()
# Out:
# <class 'numpy.ndarray'>

# %%
glo3 = cv2.imread('images/os.tif')
gray = cv.cvtColor(glo3,cv.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv.cornerHarris(gray,2,3,0.04)
#result is dilated for marking the corners, not important
dst = cv.dilate(dst,None)
# Threshold for an optimal value, it may vary depending on the image.
glo3[dst>0.01*dst.max()]=[0,0,255]


fig = plt.figure(figsize = (20,20))
ax1 = fig.add_subplot(1, 4, 1)  # first position
ax2 = fig.add_subplot(1, 4, 2)  # second position
ax3 = fig.add_subplot(1, 4, 3)   # third position
ax4 = fig.add_subplot(1, 4, 4)   # fourth position

glo = cv2.imread('images/os.tif')
glo2 = cv2.imread('images/os.tif',cv2.IMREAD_GRAYSCALE)
glo4 = cv2.imread('images/os2.bmp')
ax1.imshow(glo)
ax2.imshow(glo2, cmap="hot")
ax3.imshow(glo3)
ax4.imshow(glo4)
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ### sonidos
#
# <img src="https://www.interactivechaos.com/sites/default/files/inline-images/portada_tutorial_scipy.jpg" style="height:100px"/>
#
# http://blog.espol.edu.ec/estg1003/audio-archivo-wav-en-python/

# %%
import scipy.io.wavfile as waves
# archivo = input('archivo de sonido:' )
archivo = 'images/wav2.wav'
muestreo, sonido = waves.read(archivo)
muestreo
# Out:
# 44100

# %%
sonido
# Out:
# array([32416,  3070, -2350, ...,   -75,  -308,   -57], dtype=int16)

# %%
plt.plot(sonido, color="green")

# %% [markdown]
# Bonus

# %% [markdown]
# <img src="https://miro.medium.com/max/1838/1*dMZnyTaL4-F9UfH1HbUH5g.jpeg" />

# %%
from scipy import signal
fs = 10e3
N = 1e5
amp = 2 * np.sqrt(2)
noise_power = 0.01 * fs / 2
time = np.arange(N) / float(fs)
mod = 500*np.cos(2*np.pi*0.25*time)
carrier = amp * np.sin(2*np.pi*3e3*time + mod)
noise = np.random.normal(scale=np.sqrt(noise_power), size=time.shape)
noise *= np.exp(-time/5)
x = carrier + noise

f, t, Sxx = signal.spectrogram(sonido, fs)
plt.pcolormesh(t, f, Sxx, shading='gouraud')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
